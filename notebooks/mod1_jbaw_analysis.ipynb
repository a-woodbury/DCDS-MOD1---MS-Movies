# %%
import pandas as pd
import datetime
import numpy as np

# %%
#import datasets
movies = pd.read_csv('/Users/alphonsowoodbury/DS/code/Projects/DCDS-MOD1---MS-Movies/src/sandbox/movies_')

# %%
movies
# Out:
#    Unnamed: 0                                       Title  Year  Rated  \
# 0   tt0369610                              Jurassic World  2015  PG-13
# 1   tt0451279                                Wonder Woman  2017  PG-13
# 2   tt1396484                                          It  2017      R
# 3   tt1398426                      Straight Outta Compton  2015      R
# 4   tt1431045                                    Deadpool  2016      R
# 5   tt1477834                                     Aquaman  2018  PG-13
# 6   tt1502407                                   Halloween  2018      R
# 7   tt1502407                                   Halloween  2018      R
# 8   tt1517451                              A Star Is Born  2018      R
# 9   tt1727824                           Bohemian Rhapsody  2018  PG-13
# 10  tt1825683                               Black Panther  2018  PG-13
# 11  tt1951266       The Hunger Games: Mockingjay - Part 2  2015  PG-13
# ...
